# %% [markdown]
# # TP2 : Diabetes

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from numpy import linalg as LA
from scipy.linalg import svd
from sklearn import linear_model
from sklearn.preprocessing import scale
from sklearn.metrics import r2_score, mean_squared_error
from scipy.stats import norm
from scipy import stats
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
import math as m
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, LassoCV
import warnings
warnings.filterwarnings("ignore")
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import t

df = pd.read_csv("https://bitbucket.org/portierf/shared_files/downloads/data_dm3.csv", header=None)

# %% [markdown]
# ## Analyzing dataset

# %%
df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -1.298173 -0.162249  1.223379  1.355554  1.080171  0.634979  0.298741
# 1  0.166951 -0.338060 -0.618867  0.759366  1.134281 -0.536844 -0.075120
# 2 -0.416177 -0.205659 -1.282226  1.675500  1.523746  0.192029 -0.235840
# 3  0.867184 -0.398667  0.093501  0.025971  1.852099  0.789774  0.801775
# 4  1.193282 -0.936980 -0.725039  0.766078  0.223489 -1.584622  1.146866
#
#         7         8         9    ...       201       202       203       204  \
# 0  0.548270  0.731773  1.018645  ...  0.588278  0.210106  1.861458 -0.436399
# 1  0.970251 -0.327487  0.717310  ... -0.251054 -0.825716  0.339139  1.119430
# 2 -1.954626 -0.853309  0.892791  ...  1.283837  0.372516 -0.652557 -2.579347
# 3  0.376711  0.853689  0.247953  ...  0.446582  0.334733  0.399074 -0.884172
# 4  0.086136 -0.088780 -0.945066  ...  0.786157 -1.058179 -0.155788 -0.642504
#
#         205       206       207       208       209    210
# 0  0.279299 -1.416020 -2.332363  0.215096 -0.693319  151.0
# 1  0.225958 -0.822288  0.382838 -0.718829 -0.188993   75.0
# 2  0.139267 -1.901196  0.048210  0.220205  0.471588  141.0
# 3  0.723819  1.316367  0.088218  0.619496  1.061662  206.0
# 4  2.040010 -1.703110 -1.901502  1.778811 -0.489853  135.0
#
# [5 rows x 211 columns]

# %%
df.describe()
# Out:
#                 0             1             2             3             4    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   7.535450e-19 -1.507090e-17  5.494599e-20 -7.284269e-18  8.288995e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.149247e+00 -2.862871e+00 -3.057543e+00 -2.856903e+00 -3.102347e+00
# 25%   -6.707870e-01 -7.128394e-01 -7.160981e-01 -6.715474e-01 -6.732232e-01
# 50%    3.819503e-02  6.217421e-02  4.739406e-02  6.565749e-05 -6.111315e-03
# 75%    6.748497e-01  6.244547e-01  6.975121e-01  6.881971e-01  7.026457e-01
# max    2.547051e+00  2.567177e+00  2.965824e+00  3.057612e+00  3.173713e+00
#
#                 5             6             7             8             9    \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.712762e-17  1.971776e-17  8.540177e-18  1.029845e-17  4.018907e-18
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -2.782344e+00 -2.825318e+00 -3.626525e+00 -2.834007e+00 -2.695861e+00
# 25%   -6.951004e-01 -6.986587e-01 -6.387691e-01 -6.666746e-01 -6.930021e-01
# 50%   -1.345167e-02 -4.823057e-02  4.016636e-02  6.047571e-04  3.602406e-02
# 75%    7.155790e-01  7.200217e-01  5.788436e-01  6.298078e-01  6.629150e-01
# max    3.137950e+00  3.199205e+00  3.616718e+00  3.099090e+00  3.032505e+00
#
#        ...           201           202           203           204  \
# count  ...  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   ... -2.260635e-18 -2.637408e-17 -5.023634e-19 -1.538488e-17
# std    ...  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min    ... -3.059475e+00 -3.206539e+00 -2.585325e+00 -3.561763e+00
# 25%    ... -6.885118e-01 -5.793321e-01 -6.282190e-01 -6.190946e-01
# 50%    ... -2.994795e-02  2.540540e-02 -2.229024e-02 -6.087758e-03
# 75%    ...  6.672697e-01  6.676636e-01  5.985077e-01  7.406183e-01
# max    ...  2.677458e+00  2.806877e+00  3.255462e+00  2.811911e+00
#
#                 205           206           207           208           209  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   5.525997e-18  3.265362e-17  1.507090e-17 -4.034606e-18  1.205672e-17
# std    1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00  1.001133e+00
# min   -3.167962e+00 -2.751207e+00 -3.028940e+00 -2.675447e+00 -2.918321e+00
# 25%   -7.359866e-01 -6.374872e-01 -6.472739e-01 -7.025578e-01 -6.378171e-01
# 50%    7.677091e-03 -3.123603e-03  2.444578e-02 -4.187834e-02 -8.099075e-02
# 75%    7.000447e-01  6.440062e-01  6.313916e-01  6.929876e-01  7.249269e-01
# max    2.838960e+00  3.351254e+00  2.734481e+00  3.637684e+00  2.710260e+00
#
#               210
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000
#
# [8 rows x 211 columns]

# %% [markdown]
# ### Question 1

# %% [raw]
# La base comporte n = 442 patients et p = 10 covariables. La variable Y (dernière colonne) à expliquer est un score correspondant à l’évolution de la maladie.
# Les 211 autres colonnes représentent les variables explicatives.

# %%
df.shape
# Out:
# (442, 211)

# %% [markdown]
# ### Question 2

# %%
print ("Les covariables ont pour variance :")
df.std(axis=0,ddof=0)
# Out:
# Les covariables ont pour variance :
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# 5       1.000000
# 6       1.000000
# 7       1.000000
# 8       1.000000
# 9       1.000000
# 10      1.000000
# 11      1.000000
# 12      1.000000
# 13      1.000000
# 14      1.000000
# 15      1.000000
# 16      1.000000
# 17      1.000000
# 18      1.000000
# 19      1.000000
# 20      1.000000
# 21      1.000000
# 22      1.000000
# 23      1.000000
# 24      1.000000
# 25      1.000000
# 26      1.000000
# 27      1.000000
# 28      1.000000
# 29      1.000000
#          ...
# 181     1.000000
# 182     1.000000
# 183     1.000000
# 184     1.000000
# 185     1.000000
# 186     1.000000
# 187     1.000000
# 188     1.000000
# 189     1.000000
# 190     1.000000
# 191     1.000000
# 192     1.000000
# 193     1.000000
# 194     1.000000
# 195     1.000000
# 196     1.000000
# 197     1.000000
# 198     1.000000
# 199     1.000000
# 200     1.000000
# 201     1.000000
# 202     1.000000
# 203     1.000000
# 204     1.000000
# 205     1.000000
# 206     1.000000
# 207     1.000000
# 208     1.000000
# 209     1.000000
# 210    77.005746
# Length: 211, dtype: float64

# %%
plt.hist(df[210], bins=12, alpha=0.5)
# Out:
# (array([24., 70., 66., 46., 48., 44., 34., 30., 36., 26., 13.,  5.]),
#  array([ 25.  ,  51.75,  78.5 , 105.25, 132.  , 158.75, 185.5 , 212.25,
#         239.  , 265.75, 292.5 , 319.25, 346.  ]),
#  <a list of 12 Patch objects>)

# %%
#df.index
#rtol = 1e-05
#atol = 1e-08
#np.allclose(df,rtol,atol)
#rng = np.random.RandomState(0)
#colors = rng.rand(100)
#plt.scatter(df[1], df[210], df[2], df[100] , colors, marker='o')

# %%
u = np.random.randint(0,210,4)
#u=np.random.choice(range(210),4, replace=False)
df1 = df[u]
y=df.iloc[:,-1]
df1['y']=y

# %% [markdown]
# ### Analyse pour 4 covariables choisies au hasard + la variable explicative

# %%
#Espérance
print("L'espérance des covariables :\n",round(df[u].mean(),2))
print("\nL'espérance de la variable explicative est:",np.mean(y))
# Out:
# L'espérance des covariables :
#  124    0.0
# 140    0.0
# 10    -0.0
# 48    -0.0
# dtype: float64
#
# L'espérance de la variable explicative est: 152.13348416289594

# %%
### Variance
print("La variance de la variable explicative est :", round(y.var()))
print("\nLa variance des covariables :\n",df1.std(axis=0,ddof=0))
# Out:
# La variance de la variable explicative est : 5943
#
# La variance des covariables :
#  124     1.000000
# 140     1.000000
# 10      1.000000
# 48      1.000000
# y      77.005746
# dtype: float64

# %%
plt.figure()
plt.plot(round(df[u].var()))
plt.xlabel("Covariables")
plt.ylabel("Variance")
# Out:
# Text(0, 0.5, 'Variance')

# %% [raw]
# D'après les espérances et variances trouvées, les covariables sont centrées et normalisées. La variable explicative ne l'est pas.
#
# On peut afficher les histogrammes des pairplots ainsi que le scatter matrix des 4 covariables et en dernière ligne la variable explicative.

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(df1, palette="husl")

# %%
# %matplotlib inline
scatter_matrix(df1, alpha = 0.5, figsize = (10, 10), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f25aa050dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25aa02b2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a84ea358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8497cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a844f6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f25a840d0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8438a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a83f3470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a83f34a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a835d7b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8317198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a82c4b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a827e4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a82b0e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8268860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8225240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a81d3be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a818e5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a813ef60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8176940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8134320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a80ddcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a809a6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a8055080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f25a3fc9a20>]],
#       dtype=object)

# %% [raw]
# Il y a très peu de variables explicatives utiles. Il semble que les variables soient décorrélées.

# %% [markdown]
# ## Question 3
# ### Echantillon d’apprentissage et de test.
# On crée 2 échantillons : Xtrain (80%) et Xtest (20%)

# %%
#Taille des échantillons
df1=df.iloc[:,0:210]
Xtrain, Xtest, Ytrain, Ytest = train_test_split(df1, y, test_size=0.2)
print("Taille de Xtrain : ",Xtrain.shape)
print("Taille de Xtest : ",Xtest.shape)
# Out:
# Taille de Xtrain :  (353, 210)
# Taille de Xtest :  (89, 210)

# %%
# Matrice de covariance
cov_matrix=Xtrain.cov()
cov_matrix.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.993334 -0.135844 -0.018279 -0.299704  0.165911  0.100346 -0.026011
# 1 -0.135844  1.036827  0.053968 -0.250589 -0.100988 -0.082562  0.156046
# 2 -0.018279  0.053968  0.973801 -0.151991  0.167667 -0.074090 -0.089068
# 3 -0.299704 -0.250589 -0.151991  1.041883  0.028670 -0.057307  0.151841
# 4  0.165911 -0.100988  0.167667  0.028670  1.069072 -0.021506 -0.039517
#
#         7         8         9    ...       200       201       202       203  \
# 0 -0.169123 -0.009933 -0.026550  ... -0.165485 -0.042663  0.011127  0.001432
# 1 -0.114597  0.083610 -0.156265  ... -0.115706 -0.039760 -0.054333 -0.220232
# 2  0.020752 -0.043187 -0.148563  ...  0.161770 -0.012192  0.146287  0.093435
# 3 -0.083317  0.072833  0.012599  ...  0.116218 -0.010564 -0.128438  0.122590
# 4  0.193422 -0.049686  0.113813  ...  0.153497  0.019928  0.103869 -0.049984
#
#         204       205       206       207       208       209
# 0 -0.030077  0.007932 -0.117287 -0.045139  0.197713 -0.099762
# 1 -0.043129  0.049161 -0.036871 -0.120959 -0.103559  0.081362
# 2 -0.026286  0.039644 -0.046755 -0.293852  0.028600 -0.164431
# 3 -0.029130 -0.220963  0.107184  0.001941 -0.196673 -0.366270
# 4 -0.160061 -0.166633  0.059433 -0.037906  0.004166 -0.130426
#
# [5 rows x 210 columns]

# %%
#SVD de la matrice de covariance
u, s, vh = np.linalg.svd(cov_matrix)
plt.plot(s)

# %% [raw]
# Vu les valeurs nulles à partir de 60, il est légitime de ne garder que les premières variables.

# %%
df1=df1.iloc[0:60,:]
v160=df1
v160.shape
# Out:
# (60, 210)

# %% [markdown]
# ## Question 4
# ### Graphe de décroissance des valeurs propres de la matrice de corrélation

# %%
#Matrice de correlation
corr=Xtrain.corr()

#Calcul des valeurs propres et vecteurs propres
e=np.linalg.eigh(corr)
vecteurs_propres=np.linalg.eigh(corr)[1]

# %%
#Graphe de décroissance des valeurs propres
plt.figure()
plt.plot(sorted(e[0],reverse=True))
plt.xlabel("Covariables")
plt.ylabel("Valeurs propres")
plt.title("Décroissance valeurs propres")
# Out:
# Text(0.5, 1.0, 'Décroissance valeurs propres')

# %% [raw]
# Nous avons bien vérifié par les 2 méthodes (matrice de corrélation et matrice de covariance) que nous obtenions le même résultat. Après 60, les covariables sont quasi nulles. Pour la suite, nous prenons uniquement les 60 premières valeurs de l'ACP.
# Comme nous avons dû inverser les vecteurs propres avec reverse=True pour obtenir le graphe de décroissance des valeurs propres, il nous faut donc prendre en fait les valeurs à partir de 150.

# %%
V160=vecteurs_propres[150:]
V160.shape
# Out:
# (60, 210)

# %% [markdown]
# ## Question 5
# ### PCA before OLS
# On applique OLS avec Ytrain et X_PCA = XtrainV160, où V(1:60) contient les vecteurs propres (associés aux 60 plus grandes valeurs propres) de la matrice de covariance.
#
# On fait une régression linéaire (avec intercept), puis on trace les valeurs des coefficients (hors intercept).

# %%
X_PCA=np.dot(Xtrain,np.transpose(V160))
lin_reg_PCA = linear_model.LinearRegression(fit_intercept=True)
lin_reg_PCA.fit(X_PCA , Ytrain)
plt.figure()
plt.plot(lin_reg_PCA.coef_,'ro')

# %%
plt.plot(abs(lin_reg_PCA.coef_),'r')
plt.title('coefficients du modèle PCA before OLS')
plt.show()

# %% [markdown]
# ### Méthode des moindres carrés classique.

# %%
lr = LinearRegression()
lr.fit(Xtrain,Ytrain)
plt.plot(abs(lr.coef_))
plt.title('coefficients du modèle classique')
plt.show()

# %%
lin_reg_OLS = linear_model.LinearRegression()
lin_reg_OLS.fit(Xtrain, Ytrain)
plt.figure()
plt.plot(lin_reg_OLS.coef_,'bo')
plt.title("OLS")
# Out:
# Text(0.5, 1.0, 'OLS')

# %% [markdown]
# ## Question 6

# %%
#Valeur des intercepts pour les régressions précédentes
print("Intercept before OLS :", round(lin_reg_PCA.intercept_,2))
print("Intercept OLS classique :",round(lin_reg_OLS.intercept_,2))
#Valeur moyenne de la variable Ytrain
ymean=np.mean(Ytrain)
print("La valeur moyenne de la variable Y (sur le train set) :",round(ymean,2))
# Out:
# Intercept before OLS : 150.97
# Intercept OLS classique : 150.36
# La valeur moyenne de la variable Y (sur le train set) : 151.98

# %% [raw]
# Les intercepts ne sont pas égaux car les valeurs ne sont pas standardisées.

# %%
# Standardisation (centrage) et réduction des variables après PCA
X_PCA_centr= scale(X_PCA)
lin_reg_PCA_centr = linear_model.LinearRegression()
lin_reg_PCA_centr.fit(X_PCA_centr, Ytrain)
print("Intercept après PCA et standardisation :",round(lin_reg_PCA_centr.intercept_,2))
# Out:
# Intercept après PCA et standardisation : 151.98

# %% [raw]
# Après centrage et régression des variables après ACP, l’intercept est
# bien égal à la moyenne de Ytrain.

# %% [markdown]
# ## Question 7
# ### Résidus échantillon test pour PCA before OLS

# %%
#Résidus PCA

Xtest_PCA=np.dot(Xtest,np.transpose(V160))
Ypredict_PCA=lin_reg_PCA.predict(Xtest_PCA)
residu_PCA=Ypredict_PCA-Ytest

plt.figure()
plt.hist(residu_PCA, color="r")
plt.title("Residus de la prédiction PCA sur l’échantillon test")
# Out:
# Text(0.5, 1.0, 'Residus de la prédiction PCA sur l’échantillon test')

# %%
#Coefficient de détermination sur l’échantillon test
R2_acp=r2_score(Ytest,Ypredict_PCA)
print("Le coefficient de détermination :",round(R2_acp,2))
# Out:
# Le coefficient de détermination : 0.32

# %%
#Risque de prédiction sur l’échantillon test
#risque_prediction_PCA=(np.linalg.norm(residu_PCA))
risque_prediction_PCA=mean_squared_error(Ytest,Ypredict_PCA)
print("Le risque de prédiction est : ",round(risque_prediction_PCA,2))
# Out:
# Le risque de prédiction est :  3832.01

# %% [markdown]
# ### Résidus échantillon test  OLS

# %%
#Résidus OLS
X_OLS=Xtrain
lin_reg_OLS = linear_model.LinearRegression()
lin_reg_OLS.fit(X_OLS, Ytrain)
Ypredict_OLS=lin_reg_OLS.predict(Xtest)
residu_OLS=Ypredict_OLS-Ytest

plt.hist(residu_OLS,color="b")
plt.title("Residus échantillon test OLS")
# Out:
# Text(0.5, 1.0, 'Residus échantillon test OLS')

# %%
#Coefficient de détermination sur l’échantillon test
R2_OLS=r2_score(Ytest,Ypredict_OLS)
print("Le coefficient de détermination :",round(R2_OLS,2))
# Out:
# Le coefficient de détermination : 0.29

# %%
#Risque de prédiction sur l’échantillon test
risque_prediction_OLS=mean_squared_error(Ytest,Ypredict_OLS)
print("Le risque de prédiction est : ",round(risque_prediction_OLS,2))
# Out:
# Le risque de prédiction est :  4036.66

# %% [markdown]
# ## Question 8
# ### Forward variable selection
# On peut appliquer la méthode vue dans le cours, à chaque boucle sur k, on selectionne la variable avec la plus grande p-valeur

# %%
diabetes_X_aug = np.column_stack((np.ones((Xtrain.shape[0], 1 )), Xtrain )) 
p = diabetes_X_aug.shape[1]
n = diabetes_X_aug.shape[0]

test = np.zeros((p,p))
pval_mem = np.zeros(p)
pval = np.zeros((p,p))
resids = Ytrain

var_sel = []
var_remain = list(range(p))
in_test = []

regr = linear_model.LinearRegression(fit_intercept=False)

for k in range(p): 
    resids_mem = np.zeros((p,n))
    for i in var_remain:
        xtmp = diabetes_X_aug [:,[i]]
        regr.fit(xtmp , resids)
        #calcul de (x'x)
        xx = np.sum( diabetes_X_aug [:,[i]] ** 2 )   

        resids_mem [i,:] = regr.predict(xtmp) - resids
        sigma2_tmp = np.sum (resids_mem [i,:] ** 2) / (xx)

        test[k,i] = np.sqrt(n-1) * np.abs(regr.coef_) / (np.sqrt( sigma2_tmp )) 
        pval[k,i] =   2 * (1 - norm.cdf(test[k,i]))

    #separe en deux vecteurs la liste des variables séléctionnées et les autres
    best_var = np.argmax(test[k,:])
    var_sel.append(best_var)
    resids = resids_mem[best_var,:]
    pval_mem [k] = pval[k,best_var]
    var_remain = np.setdiff1d(var_remain,var_sel)

var_sel1=[x-1 for x in var_sel[1:]]
df=pd.DataFrame(var_sel1)
df.columns = ['Variables sélectionnées']
print ("La sélection des variables ordonnée : \n", df.head())
# Out:
# La sélection des variables ordonnée :
#     Variables sélectionnées
# 0                       58
# 1                      123
# 2                      167
# 3                      133
# 4                      129

# %% [markdown]
# ## Question 9
# ### (i) Graphes des statistiques lors de la sélection des variables
# Critère d’arrêt : On décide d’arrêter lorsque la p-valeur dépasse 0.1

# %%
var_select_ca=np.array(var_sel)[pval_mem<0.1]
var_ca=[x-1 for x in var_select_ca[1:]]
print("Les variables sélectionnées avec critère d'arrêt: \n " , var_ca)
# Out:
# Les variables sélectionnées avec critère d'arrêt:
#   [58, 123, 167, 133, 129, 13, 208, 183, 5, 31, 52, 34, 135]

# %%
def lab(s):
    return "step %s" % s

fig = plt.figure()
for s in range(3): 
    plt.plot(np.arange(p),test[s,:], '-x',label = lab(s))
    
plt.legend()
plt.title("T-stat pour chaque step")
plt.xlabel("Covariables")
plt.ylabel("t-stat")
plt.show()

# %% [markdown]
# ### (ii) Graphes des statistiques lors de la sélection des variables

# %%
for k in range(3): 
    plt.plot(np.arange(p),pval_mem, '-o', color = "orange" )
    plt.plot([-0.5,50],[.1,.1],color = "blue" )
    plt.axis(xmin = -.5,xmax = 50,ymin = -.03,ymax=0.9)
plt.title("Graphes des 50 premières p valeurs")
plt.ylabel("p-value")
plt.xlabel("steps")
# Out:
# Text(0.5, 0, 'steps')

# %% [markdown]
# ## Question 10
# ### OLS sur les variables sélectionnées

# %%
lin_reg_selec = linear_model.LinearRegression()
lin_reg_selec.fit(Xtrain.iloc[:,list(var_ca)] , Ytrain)
Ypredict_selec=lin_reg_selec.predict(Xtest.iloc[:,list(var_ca)])

### Risque de prédiction obtenu sur l’échantillon test
residu=Ytest-Ypredict_selec
risque_prediction=np.linalg.norm(residu)
risque_prediction_selec=mean_squared_error(Ytest,Ypredict_selec)
print("Le risque de prédiction est :",round(risque_prediction_selec,2))
# Out:
# Le risque de prédiction est : 3637.82

# %%
### Comparaison avec ceux de OLS et PCA before OLS
print("Les risques de prédiction :\n")
print("PCA before OLS :", round(risque_prediction_PCA,2))
print("OLS :", round(risque_prediction_OLS,2))
print("Forward selection :", round(risque_prediction_selec,2))
# Out:
# Les risques de prédiction :
#
# PCA before OLS : 3832.01
# OLS : 4036.66
# Forward selection : 3637.82

# %% [raw]
# Avec le forward selection, le risque  est moindre que la méthode OLS mais le PCA avant OLS reste meilleur.

# %% [markdown]
# ## Question 11
# ### Validation croisée
# - Split de l'échantillon train en 4 folds de façon aléatoire
# - Affichage des numéros d’échantillon sélectionnés dans chaque fold

# %%
kf = KFold(4, shuffle=True)
a=kf.get_n_splits(Xtrain)
kf.split(Xtrain.values)
sample_train=[]
for  i, data  in enumerate(kf.split(Xtrain)):
    print("\nEchantillon {:.0f} :".format(i+1))
    sample_train.append(data[1])
    print(data[1])
# Out:
# Echantillon 1 :
# [  3   4  11  12  13  15  21  22  24  38  39  44  49  53  56  62  64  65
#   68  72  77  80  81  83  84 104 120 129 132 134 136 138 140 141 142 143
#  146 148 166 167 179 180 182 189 199 200 207 210 213 214 217 220 221 224
#  226 232 233 235 241 245 246 249 250 263 265 275 277 280 283 288 289 295
#  300 302 304 306 310 311 312 319 321 330 332 337 339 343 344 347 352]
#
# Echantillon 2 :
# [  1   8  18  23  32  34  35  36  40  41  43  45  51  58  59  60  61  66
#   75  87  89  90  91  93  94  99 106 107 109 113 123 126 128 130 144 147
#  151 156 157 160 161 163 164 165 172 183 187 193 196 197 198 204 205 206
#  211 216 218 222 223 228 237 239 248 252 253 256 257 271 273 274 276 279
#  284 285 287 292 296 297 307 313 317 320 322 325 336 341 342 346]
#
# Echantillon 3 :
# [  6   7   9  14  17  27  28  30  31  37  42  46  48  50  52  69  70  71
#   78  86  88  95  96  98 108 110 116 122 124 135 137 139 145 149 153 155
#  158 162 169 171 173 175 177 178 185 186 188 190 194 195 203 209 212 215
#  225 227 229 234 238 240 243 244 247 251 259 260 268 272 278 282 286 290
#  298 301 305 308 309 314 315 316 324 326 329 331 335 338 345 350]
#
# Echantillon 4 :
# [  0   2   5  10  16  19  20  25  26  29  33  47  54  55  57  63  67  73
#   74  76  79  82  85  92  97 100 101 102 103 105 111 112 114 115 117 118
#  119 121 125 127 131 133 150 152 154 159 168 170 174 176 181 184 191 192
#  201 202 208 219 230 231 236 242 254 255 258 261 262 264 266 267 269 270
#  281 291 293 294 299 303 318 323 327 328 333 334 340 348 349 351]

# %% [markdown]
# ## Question 12
# ### Méthode de régression Ridge
# - Pour le choix du paramètre de régularisation, validation croisée sur les ”folds” définis lors de la question précédente
# - calcul du risque de prédiction et estimation du modèle
# - Moyenne des 4 risques de prédiction
# - Courbe du risque de validation croisée en fonction du paramètre de régularisation (choisir l’espace de définition pour le graphe).
# - Paramètre de régularisation optimal et valeur du risque sur le test

# %%
n_alphas = 200
alphas = np.logspace(0.1, 10, num=n_alphas)
r=[]
for alpha in alphas:
    ridge =  Ridge(alpha=alpha)
    risque = []
    for train_index, test_index in kf.split(Xtrain):
        X_train_c, X_traintest_c = Xtrain.iloc[train_index], Xtrain.iloc[test_index]
        y_train_c, y_traintest_c = Ytrain.iloc[train_index], Ytrain.iloc[test_index]
        ridge.fit(Xtrain, Ytrain)
        risque.append(mean_squared_error(ridge.predict(Xtest), Ytest))
    r.append(np.array(risque).mean())
    print('alpha :{:.2f} : moyenne des risques de prédiction: {:.2f}'.format(alpha, r[-1]))
    
alpha_ridge = alphas[np.argmin(risque)]
print("Alpha associé au risque minimum est :", alpha_ridge)
# Out:
# alpha :1.26 : moyenne des risques de prédiction: 3824.56
# alpha :1.41 : moyenne des risques de prédiction: 3823.94
# alpha :1.58 : moyenne des risques de prédiction: 3823.27
# alpha :1.78 : moyenne des risques de prédiction: 3822.55
# alpha :1.99 : moyenne des risques de prédiction: 3821.77
# alpha :2.23 : moyenne des risques de prédiction: 3820.93
# alpha :2.50 : moyenne des risques de prédiction: 3820.02
# alpha :2.81 : moyenne des risques de prédiction: 3819.02
# alpha :3.15 : moyenne des risques de prédiction: 3817.93
# alpha :3.53 : moyenne des risques de prédiction: 3816.73
# alpha :3.96 : moyenne des risques de prédiction: 3815.41
# alpha :4.44 : moyenne des risques de prédiction: 3813.95
# alpha :4.98 : moyenne des risques de prédiction: 3812.35
# alpha :5.58 : moyenne des risques de prédiction: 3810.58
# alpha :6.26 : moyenne des risques de prédiction: 3808.63
# alpha :7.02 : moyenne des risques de prédiction: 3806.50
# alpha :7.87 : moyenne des risques de prédiction: 3804.16
# alpha :8.83 : moyenne des risques de prédiction: 3801.60
# alpha :9.90 : moyenne des risques de prédiction: 3798.83
# alpha :11.10 : moyenne des risques de prédiction: 3795.82
# alpha :12.44 : moyenne des risques de prédiction: 3792.58
# alpha :13.95 : moyenne des risques de prédiction: 3789.10
# alpha :15.65 : moyenne des risques de prédiction: 3785.39
# alpha :17.55 : moyenne des risques de prédiction: 3781.44
# alpha :19.68 : moyenne des risques de prédiction: 3777.27
# alpha :22.07 : moyenne des risques de prédiction: 3772.90
# alpha :24.74 : moyenne des risques de prédiction: 3768.33
# alpha :27.75 : moyenne des risques de prédiction: 3763.60
# alpha :31.11 : moyenne des risques de prédiction: 3758.75
# alpha :34.89 : moyenne des risques de prédiction: 3753.82
# alpha :39.13 : moyenne des risques de prédiction: 3748.87
# alpha :43.87 : moyenne des risques de prédiction: 3743.97
# alpha :49.20 : moyenne des risques de prédiction: 3739.21
# alpha :55.17 : moyenne des risques de prédiction: 3734.68
# alpha :61.87 : moyenne des risques de prédiction: 3730.51
# alpha :69.38 : moyenne des risques de prédiction: 3726.83
# alpha :77.80 : moyenne des risques de prédiction: 3723.78
# alpha :87.24 : moyenne des risques de prédiction: 3721.53
# alpha :97.83 : moyenne des risques de prédiction: 3720.25
# alpha :109.70 : moyenne des risques de prédiction: 3720.12
# alpha :123.01 : moyenne des risques de prédiction: 3721.33
# alpha :137.94 : moyenne des risques de prédiction: 3724.05
# alpha :154.68 : moyenne des risques de prédiction: 3728.45
# alpha :173.46 : moyenne des risques de prédiction: 3734.71
# alpha :194.51 : moyenne des risques de prédiction: 3742.97
# alpha :218.12 : moyenne des risques de prédiction: 3753.34
# alpha :244.59 : moyenne des risques de prédiction: 3765.95
# alpha :274.28 : moyenne des risques de prédiction: 3780.87
# alpha :307.57 : moyenne des risques de prédiction: 3798.17
# alpha :344.90 : moyenne des risques de prédiction: 3817.91
# alpha :386.76 : moyenne des risques de prédiction: 3840.13
# alpha :433.70 : moyenne des risques de prédiction: 3864.86
# alpha :486.33 : moyenne des risques de prédiction: 3892.16
# alpha :545.36 : moyenne des risques de prédiction: 3922.05
# alpha :611.55 : moyenne des risques de prédiction: 3954.59
# alpha :685.77 : moyenne des risques de prédiction: 3989.81
# alpha :769.01 : moyenne des risques de prédiction: 4027.77
# alpha :862.34 : moyenne des risques de prédiction: 4068.50
# alpha :967.00 : moyenne des risques de prédiction: 4111.99
# alpha :1084.37 : moyenne des risques de prédiction: 4158.24
# alpha :1215.97 : moyenne des risques de prédiction: 4207.16
# alpha :1363.56 : moyenne des risques de prédiction: 4258.65
# alpha :1529.05 : moyenne des risques de prédiction: 4312.53
# alpha :1714.63 : moyenne des risques de prédiction: 4368.56
# alpha :1922.74 : moyenne des risques de prédiction: 4426.45
# alpha :2156.10 : moyenne des risques de prédiction: 4485.84
# alpha :2417.78 : moyenne des risques de prédiction: 4546.35
# alpha :2711.23 : moyenne des risques de prédiction: 4607.53
# alpha :3040.29 : moyenne des risques de prédiction: 4668.95
# alpha :3409.29 : moyenne des risques de prédiction: 4730.14
# alpha :3823.07 : moyenne des risques de prédiction: 4790.66
# alpha :4287.07 : moyenne des risques de prédiction: 4850.10
# alpha :4807.39 : moyenne des risques de prédiction: 4908.06
# alpha :5390.86 : moyenne des risques de prédiction: 4964.20
# alpha :6045.15 : moyenne des risques de prédiction: 5018.23
# alpha :6778.85 : moyenne des risques de prédiction: 5069.90
# alpha :7601.59 : moyenne des risques de prédiction: 5119.04
# alpha :8524.19 : moyenne des risques de prédiction: 5165.52
# alpha :9558.77 : moyenne des risques de prédiction: 5209.24
# alpha :10718.91 : moyenne des risques de prédiction: 5250.18
# alpha :12019.86 : moyenne des risques de prédiction: 5288.35
# alpha :13478.71 : moyenne des risques de prédiction: 5323.79
# alpha :15114.61 : moyenne des risques de prédiction: 5356.56
# alpha :16949.06 : moyenne des risques de prédiction: 5386.77
# alpha :19006.16 : moyenne des risques de prédiction: 5414.53
# alpha :21312.93 : moyenne des risques de prédiction: 5439.95
# alpha :23899.67 : moyenne des risques de prédiction: 5463.18
# alpha :26800.36 : moyenne des risques de prédiction: 5484.35
# alpha :30053.11 : moyenne des risques de prédiction: 5503.60
# alpha :33700.64 : moyenne des risques de prédiction: 5521.08
# alpha :37790.87 : moyenne des risques de prédiction: 5536.91
# alpha :42377.53 : moyenne des risques de prédiction: 5551.23
# alpha :47520.87 : moyenne des risques de prédiction: 5564.17
# alpha :53288.46 : moyenne des risques de prédiction: 5575.84
# alpha :59756.05 : moyenne des risques de prédiction: 5586.35
# alpha :67008.62 : moyenne des risques de prédiction: 5595.81
# alpha :75141.42 : moyenne des risques de prédiction: 5604.31
# alpha :84261.30 : moyenne des risques de prédiction: 5611.95
# alpha :94488.05 : moyenne des risques de prédiction: 5618.81
# alpha :105956.02 : moyenne des risques de prédiction: 5624.96
# alpha :118815.85 : moyenne des risques de prédiction: 5630.48
# alpha :133236.47 : moyenne des risques de prédiction: 5635.42
# alpha :149407.31 : moyenne des risques de prédiction: 5639.84
# alpha :167540.81 : moyenne des risques de prédiction: 5643.80
# alpha :187875.15 : moyenne des risques de prédiction: 5647.35
# alpha :210677.47 : moyenne des risques de prédiction: 5650.52
# alpha :236247.29 : moyenne des risques de prédiction: 5653.35
# alpha :264920.51 : moyenne des risques de prédiction: 5655.88
# alpha :297073.78 : moyenne des risques de prédiction: 5658.15
# alpha :333129.48 : moyenne des risques de prédiction: 5660.17
# alpha :373561.24 : moyenne des risques de prédiction: 5661.98
# alpha :418900.19 : moyenne des risques de prédiction: 5663.59
# alpha :469741.90 : moyenne des risques de prédiction: 5665.03
# alpha :526754.24 : moyenne des risques de prédiction: 5666.32
# alpha :590686.14 : moyenne des risques de prédiction: 5667.47
# alpha :662377.43 : moyenne des risques de prédiction: 5668.49
# alpha :742769.86 : moyenne des risques de prédiction: 5669.41
# alpha :832919.47 : moyenne des risques de prédiction: 5670.22
# alpha :934010.50 : moyenne des risques de prédiction: 5670.95
# alpha :1047370.90 : moyenne des risques de prédiction: 5671.60
# alpha :1174489.79 : moyenne des risques de prédiction: 5672.18
# alpha :1317037.04 : moyenne des risques de prédiction: 5672.70
# alpha :1476885.18 : moyenne des risques de prédiction: 5673.16
# alpha :1656134.02 : moyenne des risques de prédiction: 5673.57
# alpha :1857138.19 : moyenne des risques de prédiction: 5673.94
# alpha :2082538.14 : moyenne des risques de prédiction: 5674.27
# alpha :2335294.78 : moyenne des risques de prédiction: 5674.56
# alpha :2618728.36 : moyenne des risques de prédiction: 5674.82
# alpha :2936562.14 : moyenne des risques de prédiction: 5675.05
# alpha :3292971.26 : moyenne des risques de prédiction: 5675.26
# alpha :3692637.56 : moyenne des risques de prédiction: 5675.45
# alpha :4140811.18 : moyenne des risques de prédiction: 5675.61
# alpha :4643379.41 : moyenne des risques de prédiction: 5675.76
# alpha :5206944.09 : moyenne des risques de prédiction: 5675.89
# alpha :5838908.35 : moyenne des risques de prédiction: 5676.01
# alpha :6547573.80 : moyenne des risques de prédiction: 5676.11
# alpha :7342249.62 : moyenne des risques de prédiction: 5676.21
# alpha :8233374.87 : moyenne des risques de prédiction: 5676.29
# alpha :9232655.55 : moyenne des risques de prédiction: 5676.36
# alpha :10353218.43 : moyenne des risques de prédiction: 5676.43
# alpha :11609783.49 : moyenne des risques de prédiction: 5676.49
# alpha :13018857.23 : moyenne des risques de prédiction: 5676.54
# alpha :14598949.56 : moyenne des risques de prédiction: 5676.59
# alpha :16370816.92 : moyenne des risques de prédiction: 5676.63
# alpha :18357734.96 : moyenne des risques de prédiction: 5676.67
# alpha :20585804.27 : moyenne des risques de prédiction: 5676.70
# alpha :23084293.26 : moyenne des risques de prédiction: 5676.73
# alpha :25886022.64 : moyenne des risques de prédiction: 5676.76
# alpha :29027796.54 : moyenne des risques de prédiction: 5676.78
# alpha :32550886.00 : moyenne des risques de prédiction: 5676.80
# alpha :36501571.10 : moyenne des risques de prédiction: 5676.82
# alpha :40931748.93 : moyenne des risques de prédiction: 5676.84
# alpha :45899615.26 : moyenne des risques de prédiction: 5676.85
# alpha :51470429.10 : moyenne des risques de prédiction: 5676.86
# alpha :57717369.90 : moyenne des risques de prédiction: 5676.88
# alpha :64722498.84 : moyenne des risques de prédiction: 5676.89
# alpha :72577836.85 : moyenne des risques de prédiction: 5676.90
# alpha :81386573.39 : moyenne des risques de prédiction: 5676.90
# alpha :91264421.98 : moyenne des risques de prédiction: 5676.91
# alpha :102341140.21 : moyenne des risques de prédiction: 5676.92
# alpha :114762234.32 : moyenne des risques de prédiction: 5676.92
# alpha :128690870.54 : moyenne des risques de prédiction: 5676.93
# alpha :144310018.52 : moyenne des risques de prédiction: 5676.93
# alpha :161824854.84 : moyenne des risques de prédiction: 5676.94
# alpha :181465458.29 : moyenne des risques de prédiction: 5676.94
# alpha :203489832.16 : moyenne des risques de prédiction: 5676.95
# alpha :228187293.51 : moyenne des risques de prédiction: 5676.95
# alpha :255882273.65 : moyenne des risques de prédiction: 5676.95
# alpha :286938579.99 : moyenne des risques de prédiction: 5676.95
# alpha :321764175.03 : moyenne des risques de prédiction: 5676.96
# alpha :360816535.49 : moyenne des risques de prédiction: 5676.96
# alpha :404608661.83 : moyenne des risques de prédiction: 5676.96
# alpha :453715817.12 : moyenne des risques de prédiction: 5676.96
# alpha :508783083.81 : moyenne des risques de prédiction: 5676.96
# alpha :570533837.72 : moyenne des risques de prédiction: 5676.96
# alpha :639779250.41 : moyenne des risques de prédiction: 5676.96
# alpha :717428944.95 : moyenne des risques de prédiction: 5676.97
# alpha :804502944.92 : moyenne des risques de prédiction: 5676.97
# alpha :902145073.65 : moyenne des risques de prédiction: 5676.97
# alpha :1011637979.77 : moyenne des risques de prédiction: 5676.97
# alpha :1134419986.32 : moyenne des risques de prédiction: 5676.97
# alpha :1272103984.92 : moyenne des risques de prédiction: 5676.97
# alpha :1426498623.05 : moyenne des risques de prédiction: 5676.97
# alpha :1599632062.86 : moyenne des risques de prédiction: 5676.97
# alpha :1793778623.53 : moyenne des risques de prédiction: 5676.97
# alpha :2011488657.27 : moyenne des risques de prédiction: 5676.97
# alpha :2255622051.26 : moyenne des risques de prédiction: 5676.97
# alpha :2529385795.82 : moyenne des risques de prédiction: 5676.97
# alpha :2836376112.08 : moyenne des risques de prédiction: 5676.97
# alpha :3180625692.79 : moyenne des risques de prédiction: 5676.97
# alpha :3566656676.66 : moyenne des risques de prédiction: 5676.97
# alpha :3999540052.13 : moyenne des risques de prédiction: 5676.97
# alpha :4484962271.05 : moyenne des risques de prédiction: 5676.97
# alpha :5029299947.13 : moyenne des risques de prédiction: 5676.97
# alpha :5639703620.58 : moyenne des risques de prédiction: 5676.97
# alpha :6324191689.17 : moyenne des risques de prédiction: 5676.97
# alpha :7091755739.68 : moyenne des risques de prédiction: 5676.97
# alpha :7952478663.39 : moyenne des risques de prédiction: 5676.97
# alpha :8917667107.15 : moyenne des risques de prédiction: 5676.97
# alpha :10000000000.00 : moyenne des risques de prédiction: 5676.97
# Alpha associé au risque minimum est : 1.2589254117941673

# %%
plt.plot(np.logspace(0.1,10, num=200),r)
plt.xscale('log')
plt.plot(np.logspace(0.1, 10, num=200)[r.index(min(r))],min(r), 'o')
plt.show()

# %%
# Paramètre de régularisation optimal et valeur du risque sur le test
rmin=Ridge(alpha=np.logspace(0.1, 10, num=200)[r.index(min(r))])
rmin.fit(Xtrain, Ytrain)
param_ridge = mean_squared_error(rmin.predict(Xtest), Ytest)
print('La valeur du risque sur le test :',param_ridge)
# Out:
# La valeur du risque sur le test : 3720.123044653415

# %% [markdown]
# ## Question 13
# ### LassoCV
# - A l’aide de la fonction lassoCV de sklearn, choisir le paramètre de régularisation du LASSO.
# - Donner le risque de prédiction associé.

# %%
lasso = LassoCV()
l=lasso.fit(Xtrain,Ytrain)
#print("score :",l.score(Xtrain,Ytrain))
error_lasso=mean_squared_error(lasso.predict(Xtrain), Ytrain)
alpha=lasso.alpha_
print("alpha: ",alpha)
print("le risque de prédiction: ",round(error_lasso))
# Out:
# alpha:  6.474471111041597
# le risque de prédiction:  2936.0

# %% [markdown]
# ## Question 14
# ### Variables selectionées par le lasso
# - Appliquer la méthode Least-square LASSO aux variables sélectionnées

# %%
#print(lasso.coef_)
variables_lasso=np.nonzero(lasso.coef_)[0]

print("\nles variables sélectionnées sont :", variables_lasso)
print('le nombre de variables est : ',np.count_nonzero(lasso.coef_))
lasso_coeff=pd.Series(lasso.coef_)
# Out:
# les variables sélectionnées sont : [ 13  58 123 129 154 167 172 174]
# le nombre de variables est :  8

# %%
#linear regression
linear_lasso= linear_model.LinearRegression()
linear_lasso.fit(Xtrain[variables_lasso], Ytrain)

Ypredict=linear_lasso.predict(Xtest[variables_lasso])
m_s_error=mean_squared_error(Ypredict,Ytest)

print(f"Le risque de prédiction est : {round(m_s_error,3)}")
# Out:
# Le risque de prédiction est : 3692.45

# %% [markdown]
# ## Question 15
# ### Méthode de regression non-linéaire : Decision Tree & Random Forest
# + On apprend les différents paramètres par validation croisée et l’on donne la valeur du risque de prédiction calculé sur l’échantillon test.

# %%
#Decision tree 
dtree = DecisionTreeRegressor(max_depth=8, min_samples_leaf=0.13, random_state=3)
dtree.fit(Xtrain[variables_lasso], Ytrain)

Ypred_tree= dtree.predict(Xtest[variables_lasso])
m_s_error_tree=mean_squared_error(Ypred_tree,Ytest)

print(f"Le risque de prédiction est : {round(m_s_error_tree,3)}")
# Out:
# Le risque de prédiction est : 3981.352

# %% [raw]
# Le risque de prédiction est plus élevé avec le Decision tree qu'avec le modèle OLS.

# %%
#RF model
model_rf = RandomForestRegressor(n_estimators=500, oob_score=True, random_state=100)
model_rf.fit(Xtrain[variables_lasso], Ytrain) 
pred_train_rf= model_rf.predict(Xtest[variables_lasso])
#print(np.sqrt(mean_squared_error(y_train,pred_train_rf)))

m_s_error_rf=mean_squared_error(pred_train_rf,Ytest)
print(f"Le risque de prédiction est : {round(m_s_error_rf,3)}")
# Out:
# Le risque de prédiction est : 3542.647

# %% [raw]
# La performance du forest model est supérieure à celle de l'arbre de décision.
